# %%
import googlemaps


GOOGLE_MAPS_API_KEY='AIzaSyB3UHXOpfDw1tJo5LDDOGZ3luzr-qQkec0'

def get_cep(cep):
    import googlemaps

    gmaps = googlemaps.Client(key='AIzaSyB3UHXOpfDw1tJo5LDDOGZ3luzr-qQkec0')

    address = ', '.join([cep, 'Brasil'])
    return gmaps.geocode(address)

# %%
get_cep('01401001')
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# ~/.virtualenvs/ijupyter/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/.virtualenvs/ijupyter/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# ...
