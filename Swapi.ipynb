# %%
import keyboard

keyboard.is_pressed('w')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-07a8c1223c6c> in <module>
#       1 import keyboard
#       2
# ----> 3 keyboard.is_pressed('w')
#
# ~/.virtualenvs/ijupyter/lib/python3.6/site-packages/keyboard/__init__.py in is_pressed(hotkey)
#     408         is_pressed('ctrl+space') #-> True
#     409     """
# --> 410     _listener.start_if_necessary()
#     411
#     412     if _is_number(hotkey):
#
# ~/.virtualenvs/ijupyter/lib/python3.6/site-packages/keyboard/_generic.py in start_if_necessary(self)
#      33         try:
#      34             if not self.listening:
# ---> 35                 self.init()
#      36
#      37                 self.listening = True
#
# ~/.virtualenvs/ijupyter/lib/python3.6/site-packages/keyboard/__init__.py in init(self)
#     194
#     195     def init(self):
# --> 196         _os_keyboard.init()
#     197
# ...
