# %%
import pycep_correios


def get_cep_from_correios(cep):
    _cep = pycep_correios.consultar_cep(cep)
    return _cep

# %%
get_cep_from_correios('70803-260')
# Out:
# {'bairro': 'Vila Planalto',
#  'cep': '70803260',
#  'cidade': 'Brasília',
#  'end': 'Rua Espírito Santo',
#  'uf': 'DF',
#  'complemento2': '(Acamp Rabelo)',
#  'unidadesPostagem': []}
