# %%
import pycep_correios


def get_cep_from_correios(cep):
    _cep = pycep_correios.consultar_cep(cep)
    return _cep

# %%
get_cep_from_correios('01401001')
# Out:
# {'bairro': 'Jardim Paulista',
#  'cep': '01401001',
#  'cidade': 'São Paulo',
#  'end': 'Avenida Brigadeiro Luís Antônio',
#  'uf': 'SP',
#  'complemento2': '- de 3141 a 3999 - lado ímpar',
#  'unidadesPostagem': []}
